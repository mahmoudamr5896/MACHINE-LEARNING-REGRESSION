# %% [markdown]
# ### import library :

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
 plt.figure(figsize=(15,20))

# %% [markdown]
# #### loading data :

# %%
aple = pd.read_csv('NOTE BOOK/AAPL.csv')
amzon = pd.read_csv('NOTE BOOK/AMZN.csv')
meta = pd.read_csv('NOTE BOOK/META.csv')
google = pd.read_csv('NOTE BOOK/GOOGL.csv')
amzon = pd.read_csv('NOTE BOOK/AMZN.csv')

# %%
aple.set_index(aple['Date'])
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2010-01-04  2010-01-04    7.622500    7.660714    7.585000    7.643214
# 2010-01-05  2010-01-05    7.664286    7.699643    7.616071    7.656429
# 2010-01-06  2010-01-06    7.656429    7.686786    7.526786    7.534643
# 2010-01-07  2010-01-07    7.562500    7.571429    7.466071    7.520714
# 2010-01-08  2010-01-08    7.510714    7.571429    7.466429    7.570714
# ...                ...         ...         ...         ...         ...
# 2022-12-22  2022-12-22  134.350006  134.559998  130.300003  132.229996
# 2022-12-23  2022-12-23  130.919998  132.419998  129.639999  131.860001
# 2022-12-27  2022-12-27  131.380005  131.410004  128.720001  130.029999
# 2022-12-28  2022-12-28  129.669998  131.029999  125.870003  126.040001
# 2022-12-29  2022-12-29  127.989998  130.479996  127.730003  129.610001
#
#              Adj Close     Volume
# Date
# 2010-01-04    6.515213  493729600
# ...

# %%
aple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3271 non-null   object
#  1   Open       3271 non-null   float64
#  2   High       3271 non-null   float64
#  3   Low        3271 non-null   float64
#  4   Close      3271 non-null   float64
#  5   Adj Close  3271 non-null   float64
#  6   Volume     3271 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 179.0+ KB

# %%
aple .describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     51.274171    51.845876    50.708548    51.297154    49.445122
# std      47.316509    47.926721    46.720115    47.344344    47.810585
# min       6.870357     7.000000     6.794643     6.858929     5.846675
# 25%      18.965894    19.121607    18.779999    18.965536    16.625739
# 50%      29.745001    29.980000    29.555000    29.812500    27.385101
# 75%      56.897499    57.256248    56.435000    56.761250    54.876044
# max     182.630005   182.940002   179.119995   182.009995   180.959732
#
#              Volume
# count  3.271000e+03
# mean   2.563255e+08
# std    2.225768e+08
# min    3.519590e+07
# 25%    1.023724e+08
# 50%    1.666740e+08
# 75%    3.457554e+08
# max    1.880998e+09

# %%
aple.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # explore data

# %%
sns.pairplot(aple)

# %%
sns.pairplot(amzon)

# %%
sns.pairplot(google)

# %%
sns.pairplot(meta)

# %%
# !pip install plotly

# %%
import plotly.tools

# %%
import plotly.colors

# %%
amzon.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     58.937204    59.610805    58.183281    58.905287    58.905287
# std      54.138607    54.785319    53.410691    54.085034    54.085034
# min       5.296500     5.564500     5.290000     5.430500     5.430500
# 25%      13.343750    13.474500    13.197000    13.326250    13.326250
# 50%      36.325001    36.500000    36.027500    36.382500    36.382500
# 75%      93.025002    94.177250    92.023250    93.138001    93.138001
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  3.271000e+03
# mean   8.833999e+07
# std    5.309249e+07
# min    1.762600e+07
# 25%    5.610700e+07
# 50%    7.459200e+07
# 75%    1.037120e+08
# max    8.484220e+08

# %%
google.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   112.008338  113.580572  110.380915  111.933412  111.933412
# std     16.061858   16.094546   15.726139   15.899375   15.899375
# min     85.400002   86.519997   83.339996   83.430000   83.430000
# 25%     98.204998   99.779999   97.069997   98.455000   98.455000
# 50%    111.491753  113.312748  109.965000  111.622749  111.622749
# 75%    121.713623  122.960249  119.747500  122.125252  122.125252
# max    151.250000  151.546494  145.522507  148.000000  148.000000
#
#              Volume
# count  2.520000e+02
# mean   3.450729e+07
# std    1.334196e+07
# min    9.701400e+06
# 25%    2.597800e+07
# 50%    3.173255e+07
# 75%    3.991450e+07
# max    1.232000e+08

# %%
meta.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2688.000000  2688.000000  2688.000000  2688.000000  2688.000000
# mean    147.874275   149.757980   146.003795   147.913244   147.913244
# std      86.734656    87.818979    85.682869    86.763257    86.763257
# min      18.080000    18.270000    17.549999    17.730000    17.730000
# 25%      77.967500    78.627499    77.145001    77.980000    77.980000
# 50%     141.620002   143.415000   140.550003   142.065002   142.065002
# 75%     191.070000   193.807499   188.255001   190.854996   190.854996
# max     381.679993   384.329987   378.809998   382.179993   382.179993
#
#              Volume
# count  2.688000e+03
# mean   3.117815e+07
# std    2.713267e+07
# min    5.913100e+06
# 25%    1.622585e+07
# 50%    2.323900e+07
# 75%    3.603725e+07
# max    5.735764e+08

# %%
aple.set_index(aple['Date']=='2022-12-29',)
#\aple(aple['date']=='2022')
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# Date
# False  2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# False  2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526476
# False  2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422664
# False  2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410790
# False  2010-01-08    7.510714    7.571429    7.466429    7.570714    6.453412
# ...           ...         ...         ...         ...         ...         ...
# False  2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# False  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# False  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# False  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# True   2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
#
#           Volume
# Date
# ...

# %%
date_aple  =aple.set_index(aple['Date'])
date_aple
# Out:
#                   Date        Open        High         Low       Close  \
# Date
# 2010-01-04  2010-01-04    7.622500    7.660714    7.585000    7.643214
# 2010-01-05  2010-01-05    7.664286    7.699643    7.616071    7.656429
# 2010-01-06  2010-01-06    7.656429    7.686786    7.526786    7.534643
# 2010-01-07  2010-01-07    7.562500    7.571429    7.466071    7.520714
# 2010-01-08  2010-01-08    7.510714    7.571429    7.466429    7.570714
# ...                ...         ...         ...         ...         ...
# 2022-12-22  2022-12-22  134.350006  134.559998  130.300003  132.229996
# 2022-12-23  2022-12-23  130.919998  132.419998  129.639999  131.860001
# 2022-12-27  2022-12-27  131.380005  131.410004  128.720001  130.029999
# 2022-12-28  2022-12-28  129.669998  131.029999  125.870003  126.040001
# 2022-12-29  2022-12-29  127.989998  130.479996  127.730003  129.610001
#
#              Adj Close     Volume
# Date
# 2010-01-04    6.515213  493729600
# ...

# %%
(aple['Open'].max())
# Out:
# 182.630005

# %%
import datetime as dt

# %%
aple['Date']= pd.to_datetime(aple['Date'])

# %%
aple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# ## the most stoke Closed in four companies :
#  - amzon
#  - google
#  - meta
#  -aple

# %%
(amzon['Close'].max()),(google['Close'].max()),(meta['Close'].max()),(aple['Close'].max())
# Out:
# (186.570496, 148.0, 382.179993, 182.009995)

# %% [markdown]
# ## the most stoke opened in four companies :
#  - amzon
#  - google
#  - meta
#  -aple

# %%
(amzon['Open'].max()),(google['Open'].max()),(meta['Open'].max()),(aple['Open'].max())
# Out:
# (187.199997, 151.25, 381.679993, 182.630005)

# %% [markdown]
# ## the most stoke be High in four companies :
#  - amzon
#  - google
#  - meta
#  -aple

# %%
(amzon['High'].max()),(google['High'].max()),(meta['High'].max()),(aple['High'].max())
# Out:
# (188.654007, 151.546494, 384.329987, 182.940002)

# %%
amzon.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
amzon['Date']= pd.to_datetime(amzon['Date'])

# %%
amzon.dtypes
# Out:
# Date         string
# Open         string
# High         string
# Low          string
# Close        string
# Adj Close    string
# Volume       string
# dtype: object

# %%
open =aple[['Open','Close','Date']]

# %%
open.iplot(kind='histogram', filename='simple-histogram-chart')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1412\1340848040.py in <module>
# ----> 1 open.iplot(kind='histogram', filename='simple-histogram-chart')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.isna().sum()
# Out:
# Open     0
# Close    0
# dtype: int64

# %%
df=open#.astype('float')

# %%
df['Open'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# dtype: int64

# %%
df.dtypes
# Out:
# Open     float64
# Close    float64
# dtype: object

# %%
df1 = pd.DataFrame(data=df,dtype='float64')

# %%
df1.dtypes
# Out:
# Open     float64
# Close    float64
# dtype: object

# %%
plt.plot(df)
plt.show()

# %%
df.set_index(df['Date'])
# Out:
#                   Open       Close       Date
# Date
# 2010-01-04    7.622500    7.643214 2010-01-04
# 2010-01-05    7.664286    7.656429 2010-01-05
# 2010-01-06    7.656429    7.534643 2010-01-06
# 2010-01-07    7.562500    7.520714 2010-01-07
# 2010-01-08    7.510714    7.570714 2010-01-08
# ...                ...         ...        ...
# 2022-12-22  134.350006  132.229996 2022-12-22
# 2022-12-23  130.919998  131.860001 2022-12-23
# 2022-12-27  131.380005  130.029999 2022-12-27
# 2022-12-28  129.669998  126.040001 2022-12-28
# 2022-12-29  127.989998  129.610001 2022-12-29
#
# [3271 rows x 3 columns]

# %%
df.iloc[3250:,]
# Out:
#             Open       Close       Date
# 3250  141.399994  148.029999 2022-11-30
# 3251  148.210007  148.309998 2022-12-01
# 3252  145.960007  147.809998 2022-12-02
# 3253  147.770004  146.630005 2022-12-05
# 3254  147.070007  142.910004 2022-12-06
# 3255  142.190002  140.940002 2022-12-07
# 3256  142.360001  142.649994 2022-12-08
# 3257  142.339996  142.160004 2022-12-09
# 3258  142.699997  144.490005 2022-12-12
# 3259  149.500000  145.470001 2022-12-13
# 3260  145.350006  143.210007 2022-12-14
# 3261  141.110001  136.500000 2022-12-15
# 3262  136.690002  134.509995 2022-12-16
# 3263  135.110001  132.369995 2022-12-19
# 3264  131.389999  132.300003 2022-12-20
# 3265  132.979996  135.449997 2022-12-21
# 3266  134.350006  132.229996 2022-12-22
# 3267  130.919998  131.860001 2022-12-23
# 3268  131.380005  130.029999 2022-12-27
# 3269  129.669998  126.040001 2022-12-28
# 3270  127.989998  129.610001 2022-12-29

# %%
aple_2010=aple.loc[1:251,]
aple_2010
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 1    2010-01-05   7.664286   7.699643   7.616071   7.656429   6.526476
# 2    2010-01-06   7.656429   7.686786   7.526786   7.534643   6.422664
# 3    2010-01-07   7.562500   7.571429   7.466071   7.520714   6.410790
# 4    2010-01-08   7.510714   7.571429   7.466429   7.570714   6.453412
# 5    2010-01-11   7.600000   7.607143   7.444643   7.503929   6.396483
# ..          ...        ...        ...        ...        ...        ...
# 247  2010-12-27  11.530357  11.622857  11.482857  11.595714   9.884394
# 248  2010-12-28  11.639643  11.666429  11.609286  11.623929   9.908445
# 249  2010-12-29  11.650714  11.658929  11.610714  11.617500   9.902965
# 250  2010-12-30  11.624286  11.625357  11.537500  11.559286   9.853346
# 251  2010-12-31  11.533929  11.552857  11.475357  11.520000   9.819854
#
#         Volume
# 1    601904800
# 2    552160000
# 3    477131200
# 4    447610800
# 5    462229600
# ..         ...
# ...

# %%
aple_2022=aple.loc[3021:,]
aple_2022
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3021  2022-01-03  177.830002  182.880005  177.710007  182.009995  180.959732
# 3022  2022-01-04  182.630005  182.940002  179.119995  179.699997  178.663071
# 3023  2022-01-05  179.610001  180.169998  174.639999  174.919998  173.910660
# 3024  2022-01-06  172.699997  175.300003  171.639999  172.000000  171.007523
# 3025  2022-01-07  172.889999  174.139999  171.029999  172.169998  171.176529
# ...          ...         ...         ...         ...         ...         ...
# 3266  2022-12-22  134.350006  134.559998  130.300003  132.229996  132.229996
# 3267  2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 3268  2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 3269  2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 3270  2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
#
#          Volume
# 3021  104487900
# ...

# %%
amzon_2022=amzon.loc[3021:,]
amzon_2022
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3021  2022-01-03  167.550003  170.703506  166.160507  170.404495  170.404495
# 3022  2022-01-04  170.438004  171.399994  166.349503  167.522003  167.522003
# 3023  2022-01-05  166.882996  167.126495  164.356995  164.356995  164.356995
# 3024  2022-01-06  163.450500  164.800003  161.936996  163.253998  163.253998
# 3025  2022-01-07  163.839005  165.243500  162.031006  162.554001  162.554001
# ...          ...         ...         ...         ...         ...         ...
# 3266  2022-12-22   85.519997   85.680000   82.250000   83.790001   83.790001
# 3267  2022-12-23   83.250000   85.779999   82.930000   85.250000   85.250000
# 3268  2022-12-27   84.970001   85.349998   83.000000   83.040001   83.040001
# 3269  2022-12-28   82.800003   83.480003   81.690002   81.820000   81.820000
# 3270  2022-12-29   82.870003   84.550003   82.550003   84.180000   84.180000
#
#         Volume
# 3021  63520000
# ...

# %%
google_2022=google.loc[:235,]
google_2022
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-01-25  128.740005  129.399002  126.500504  126.934998  126.934998
# 1    2022-01-26  131.119003  133.000000  127.141998  129.233002  129.233002
# 2    2022-01-27  131.304001  132.652496  128.932495  129.005005  129.005005
# 3    2022-01-28  129.658997  133.356506  128.485001  133.350998  133.350998
# 4    2022-01-31  134.162003  135.473007  132.209503  135.303497  135.303497
# ..          ...         ...         ...         ...         ...         ...
# 231  2022-12-23   87.110001   89.550003   87.070000   89.230003   89.230003
# 232  2022-12-27   88.800003   88.940002   87.010002   87.389999   87.389999
# 233  2022-12-28   86.980003   88.040001   85.940002   86.019997   86.019997
# 234  2022-12-29   86.620003   88.849998   86.610001   88.449997   88.449997
# 235  2022-12-30   86.980003   88.300003   86.570000   88.230003   88.230003
#
#        Volume
# 0    46960000
# 1    49130000
# ...

# %%
meta_2022=meta.loc[2422:2672,]
meta_2022
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2422  2022-01-03  338.299988  341.079987  337.190002  338.540009  338.540009
# 2423  2022-01-04  339.950012  343.089996  331.869995  336.529999  336.529999
# 2424  2022-01-05  333.019989  335.760010  323.839996  324.170013  324.170013
# 2425  2022-01-06  322.820007  339.170013  322.720001  332.459991  332.459991
# 2426  2022-01-07  332.739990  337.000000  328.880005  331.790009  331.790009
# ...          ...         ...         ...         ...         ...         ...
# 2668  2022-12-23  116.029999  118.180000  115.540001  118.040001  118.040001
# 2669  2022-12-27  117.930000  118.599998  116.050003  116.879997  116.879997
# 2670  2022-12-28  116.250000  118.150002  115.510002  115.620003  115.620003
# 2671  2022-12-29  116.400002  121.029999  115.769997  120.260002  120.260002
# 2672  2022-12-30  118.160004  120.419998  117.739998  120.339996  120.339996
#
#         Volume
# 2422  14537900
# ...

# %%
meta_2022['Open'].max(),google_2022['Open'].max(),amzon_2022['Open'].max(),aple['Open'].max()
# Out:
# (339.950012, 151.25, 170.438004, 182.630005)

# %%
meta_2022.loc[2423]
# Out:
# Date         2022-01-04
# Open         339.950012
# High         343.089996
# Low          331.869995
# Close        336.529999
# Adj Close    336.529999
# Volume         15998000
# Name: 2423, dtype: object

# %%
aple_2022['Open'].idxmax()
# Out:
# 3022

# %%
google_2022.loc[6]
# Out:
# Date         2022-02-02
# Open             151.25
# High         151.546494
# Low          145.522507
# Close             148.0
# Adj Close         148.0
# Volume        123200000
# Name: 6, dtype: object

# %%
amzon_2022.loc[3022]
# Out:
# Date         2022-01-04
# Open         170.438004
# High         171.399994
# Low          166.349503
# Close        167.522003
# Adj Close    167.522003
# Volume         70726000
# Name: 3022, dtype: object

# %%
aple_2022.loc[3022]
# Out:
# Date         2022-01-04
# Open         182.630005
# High         182.940002
# Low          179.119995
# Close        179.699997
# Adj Close    178.663071
# Volume         99310400
# Name: 3022, dtype: object

# %%
plt.hist(aple_2022['Open'])
# Out:
# (array([11., 17., 35., 41., 28., 26., 29., 32., 25.,  6.]),
#  array([127.989998 , 133.4539987, 138.9179994, 144.3820001, 149.8460008,
#         155.3100015, 160.7740022, 166.2380029, 171.7020036, 177.1660043,
#         182.630005 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(amzon_2022['Open'])
# Out:
# (array([18., 22., 24., 43., 29., 18., 27., 24., 26., 19.]),
#  array([ 82.800003 ,  91.5638031, 100.3276032, 109.0914033, 117.8552034,
#         126.6190035, 135.3828036, 144.1466037, 152.9104038, 161.6742039,
#         170.438004 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(meta_2022['Open'])
# Out:
# (array([25., 41., 39., 46., 55., 22.,  1.,  0.,  8., 14.]),
#  array([ 90.080002, 115.067003, 140.054004, 165.041005, 190.028006,
#         215.015007, 240.002008, 264.989009, 289.97601 , 314.963011,
#         339.950012]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(google_2022['Open'])
xlabel = 'gogle'

# %%
plt.boxplot(aple_2022['Open'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24dbea38a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24dbea445e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24dbea389d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24dbea44fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24dbea3e4c0>],
#  'means': []}

# %%
plt.boxplot(meta_2022['Open'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24dbe707b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24dbe7072e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24dbe707730>],
#  'medians': [<matplotlib.lines.Line2D at 0x24dbed6f6a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24dbed6f970>],
#  'means': []}

# %%
aple_2022['Open'].iplot(kind='histogram', filename='simple-histogram-chart')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10468\1498214292.py in <module>
# ----> 1 aple_2022['Open'].iplot(kind='histogram', filename='simple-histogram-chart')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'iplot'

# %%
plt.plot(meta_2022['Open'])
plt.plot(meta_2022['High'])
plt.plot(meta_2022['Low'])
plt.plot(meta_2022['Close'])

# %%
plt.plot(google_2022['Open'])
plt.plot(google_2022['High'])
plt.plot(google_2022['Low'])
plt.plot(google_2022['Close'])

# %%
plt.plot(amzon_2022['Open'])
plt.plot(amzon_2022['High'])
plt.plot(amzon_2022['Low'])
plt.plot(amzon_2022['Close'])

# %%
plt.plot(aple_2022['Open'])
plt.plot(aple_2022['High'])
plt.plot(aple_2022['Low'])
plt.plot(aple_2022['Close'])

# %%
plt.fill_between(aple['Open'],aple['Close'],aple['High'])

# %%
plt.plot(aple_2022['Open'])
plt.plot(meta_2022['Open'])
plt.plot(google_2022['Open'])
plt.plot(amzon_2022['Open'])

# %%
plt.bar(meta['Open'],meta['Close'])
# Out:
# <BarContainer object of 2688 artists>

# %%
plt.Figure(figsize=(20,10))

# %%
aple_2022.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000
# mean   154.908280  157.015640  152.792360  154.934680  154.479726
# std     12.981506   12.849824   13.036034   12.986333   12.777336
# min    127.989998  130.479996  125.870003  126.040001  126.040001
# 25%    144.410004  146.757499  142.559998  144.817501  144.507553
# 50%    154.254998  156.055001  151.970001  154.275002  153.827285
# 75%    166.279995  168.050000  164.112496  165.967502  165.271942
# max    182.630005  182.940002  179.119995  182.009995  180.959732
#
#              Volume
# count  2.500000e+02
# mean   8.795388e+07
# std    2.369438e+07
# min    3.519590e+07
# 25%    7.227205e+07
# 50%    8.375050e+07
# 75%    9.695358e+07
# max    1.826020e+08

# %%
amzon_2022.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000
# mean   126.490872  128.597294  124.079924  126.267214  126.267214
# std     23.808969   23.934592   23.602944   23.802625   23.802625
# min     82.800003   83.480003   81.690002   81.820000   81.820000
# 25%    108.612999  112.648251  106.677499  108.927498  108.927498
# 50%    122.739998  124.534000  120.664997  122.884998  122.884998
# 75%    146.864498  149.660004  143.779629  145.965755  145.965755
# max    170.438004  171.399994  167.868500  170.404495  170.404495
#
#              Volume
# count  2.500000e+02
# mean   7.613542e+07
# std    3.408260e+07
# min    3.508860e+07
# 25%    5.504142e+07
# 50%    6.674845e+07
# 75%    8.512030e+07
# max    2.726620e+08

# %%
meta_2022.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   180.239004  183.843068  176.878407  180.187690  180.187690
# std     56.820096   57.593443   55.706313   56.658923   56.658923
# min     90.080002   90.459999   88.089996   88.910004   88.910004
# 25%    137.819999  140.600006  135.349998  138.059998  138.059998
# 50%    169.979996  172.399994  167.279999  170.160004  170.160004
# 75%    207.019996  211.535004  201.720001  207.655007  207.655007
# max    339.950012  343.089996  337.190002  338.540009  338.540009
#
#              Volume
# count  2.510000e+02
# mean   3.555830e+07
# std    2.386647e+07
# min    1.200760e+07
# 25%    2.332610e+07
# 50%    2.949970e+07
# 75%    3.881280e+07
# max    2.323166e+08

# %%
google_2022.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  236.000000  236.000000  236.000000  236.000000  236.000000
# mean   113.408521  114.992339  111.746019  113.302718  113.302718
# std     15.609783   15.625894   15.288061   15.469039   15.469039
# min     85.400002   86.519997   83.339996   83.430000   83.430000
# 25%     99.780001  101.189999   98.822502  100.030002  100.030002
# 50%    112.693249  114.444999  111.155750  112.952000  112.952000
# 75%    126.431500  129.512878  125.033875  126.057873  126.057873
# max    151.250000  151.546494  145.522507  148.000000  148.000000
#
#              Volume
# count  2.360000e+02
# mean   3.458394e+07
# std    1.358492e+07
# min    9.701400e+06
# 25%    2.570118e+07
# 50%    3.185955e+07
# 75%    3.996500e+07
# max    1.232000e+08

# %%
amzon_2022.to_csv('amzon_2022_csv')

# %%
aple_2022.to_csv('aple_2022_csv')

# %%
meta_2022.to_csv('meta_2022_csv')

# %%
google_2022.to_csv('google_2022_csv')
